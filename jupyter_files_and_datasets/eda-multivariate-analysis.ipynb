# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#        sector property_type               society  price  price_per_sqft  \
# 0   sector 95          flat         the roselia 2   0.45          6475.0
# 1   sector 78          flat  umang monsoon breeze   1.20          6493.0
# 2     manesar          flat  hsiidc sidco aravali   0.91          3516.0
# 3  sector 108          flat            sobha city   3.35         13266.0
# 4  sector 108          flat            sobha city   1.90         13758.0
#
#      area                                       areaWithType  bedRoom  \
# 0   695.0  Built Up area: 695 (64.57 sq.m.)Carpet area: 5...        2
# 1  1848.0  Super Built up area 2250(209.03 sq.m.)Carpet a...        3
# 2  2588.0  Super Built up area 2588(240.43 sq.m.)Built Up...        3
# 3  2525.0           Super Built up area 2072.9(192.58 sq.m.)        3
# 4  1381.0              Super Built up area 1381(128.3 sq.m.)        2
#
#    bathroom balcony  floorNum facing            agePossession  \
# ...

# %% [markdown]
# ## property_type vs price

# %%
# houses ahave very high prices

# %%
# the price of houses have very high range

# %% [markdown]
# ## property_type vs area

# %%
# the area of houses are high in comparison to flats

# %%
# massive outliers

# %%
# removing that crazy outlier

# %%
# boxplot

# %% [markdown]
# ## property_type vs price_per_sqft

# %%
# check outliers

# their is messed up. area is less and price of flat is very high ,then obviously price_per_sqft will increses very high . 
# and this is not outliers this are the data errors

# %% [markdown]
# ## property_type vs bedroom

# %%
# heatmap

# %%
# checking outliers
