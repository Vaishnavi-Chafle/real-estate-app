# %%
import numpy as np
import pandas as pd

# %%
# import the files
flats = pd.read_csv("flats_cleaned.csv")
houses = pd.read_csv("house_cleaned.csv")

# %%
# concat
df = pd.concat([flats,houses],ignore_index = True)

# %%
# This line shuffles your dataset completely and resets row numbers.

df = df.sample(df.shape[0],ignore_index= True)
df.head()
# Out:
#                                        property_name property_type  \
# 0             3 Bedroom House for sale in Sohna Road         house
# 1  4 Bedroom House for sale in Hsiidc Plot Sector...         house
# 2      4 Bedroom House for sale in Sector 54 Gurgaon         house
# 3                  1 BHK Flat in Block A Surya Vihar          flat
# 4      6 Bedroom House for sale in Sector 14 Gurgaon         house
#
#                  society  price  price_per_sqft     area  \
# 0            independent   6.25          6944.0  9000.58
# 1            independent  10.00        122222.0   818.18
# 2            independent   3.75        234375.0   160.00
# 3  shree shyam residency   0.23          5000.0   460.00
# 4            independent   6.40         20317.0  3150.07
#
#                                         areaWithType    bedRoom    bathroom  \
# 0                       Plot area 1000(836.13 sq.m.)          3           3
# 1                         Plot area 900(83.61 sq.m.)          4           4
# 2                         Plot area 160(14.86 sq.m.)          4           4
# 3                     Carpet area: 460 (42.74 sq.m.)  1 Bedroom  1 Bathroom
# 4  Plot area 350(292.64 sq.m.)Built Up area: 349 ...          6           6
#
#      balcony additionalRoom  \
# 0          0  not available
# 1         3+   servant room
# 2          3   servant room
# 3  1 Balcony  not available
# 4         3+         others
#
#                                              address  floorNum      facing  \
# 0                       Sohna Road, Gurgaon, Haryana       1.0          Na
# 1  Hsiidc Plot Sector 1 Imt Manesar, Gurgaon, Har...       1.0  North-East
# 2                Sector 54 Gurgaon, Gurgaon, Haryana       3.0        East
# 3  Plot No. 833, Block A Surya Vihar, Gurgaon, Ha...       2.0       South
# 4     Sector 14, Sector 14 Gurgaon, Gurgaon, Haryana       3.0       North
#
#       agePossession                                    nearbyLocations  \
# 0  5 to 10 Year Old  ['Rajiv Chowk Mosque', 'Standard chartered ATM...
# 1         undefined                                                NaN
# 2  5 to 10 Year Old  ['Sector 53-54 metro station', 'Sector 54 chow...
# 3   1 to 5 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Shre...
# 4      10+ Year Old  ['Sheetla Mata Mandir', 'Hsbc bank ATM', 'Hdfc...
#
#                                          description  \
# 0  We are proud owners of house/villa available f...
# 1  Hsiidc plot for sae sec-1 imt manesar Plot siz...
# 2  East facing old house ready to move in f block...
# 3  1 drawing room\n1 bed room\n1 bathroom\n1 balc...
# 4  House for sale plot size 350 sqyard corner 20 ...
#
#                                       furnishDetails  \
# 0                                                 []
# 1                                                NaN
# 2  ['6 Fan', '1 Exhaust Fan', '3 Geyser', '7 Ligh...
# 3  ['1 Wardrobe', '1 Geyser', '1 Light', '1 Modul...
# 4                                                NaN
#
#                                             features  \
# 0                                                NaN
# 1  ['Feng Shui / Vaastu Compliant', 'Piped-gas', ...
# 2  ['Maintenance Staff', 'Water Storage', 'Waste ...
# 3               ['Security / Fire Alarm', 'Lift(s)']
# 4  ['Maintenance Staff', 'Water Storage', 'Park',...
#
#                                               rating
# 0                                                NaN
# 1                                                NaN
# 2  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 3                                                NaN
# 4  ['Environment4 out of 5', 'Safety4 out of 5', ...

# %%
# Export

df.to_csv("gurgaon_properties.csv",index = False)
