# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option("display.max_columns",None)

# %%
df = pd.read_csv("gurgaon_properties_missing_value_imputation.csv")

# %%
df.shape
# Out:
# (3554, 18)

# %%
df.head()
# Out:
#        sector property_type               society  price  price_per_sqft  \
# 0   sector 95          flat         the roselia 2   0.45          6475.0
# 1   sector 78          flat  umang monsoon breeze   1.20          6494.0
# 2     manesar          flat  hsiidc sidco aravali   0.91          3516.0
# 3  sector 108          flat            sobha city   3.35         13267.0
# 4  sector 108          flat            sobha city   1.90         13758.0
#
#    bedRoom  bathroom balcony  floorNum            agePossession  \
# 0        2         2       2      19.0             New Property
# 1        3         3       2       8.0  Moderately New Property
# 2        3         3      3+       8.0  Moderately New Property
# 3        3         4       2      19.0             New Property
# 4        2         2       2       8.0  Relatively new property
#
#    built_up_area  servant room  study room  others  pooja room  store room  \
# ...

# %%
train_df = df.drop(columns = ["society","price_per_sqft"])

# %%
train_df.head()
# Out:
#        sector property_type  price  bedRoom  bathroom balcony  floorNum  \
# 0   sector 95          flat   0.45        2         2       2      19.0
# 1   sector 78          flat   1.20        3         3       2       8.0
# 2     manesar          flat   0.91        3         3      3+       8.0
# 3  sector 108          flat   3.35        3         4       2      19.0
# 4  sector 108          flat   1.90        2         2       2       8.0
#
#              agePossession  built_up_area  servant room  study room  others  \
# 0             New Property          695.0             0           0       0
# 1  Moderately New Property         2045.0             0           0       0
# 2  Moderately New Property         1900.0             1           0       0
# 3             New Property         2525.0             0           0       0
# 4  Relatively new property         1250.0             0           0       0
#
#    pooja room  store room  furnishing_type  luxury_score
# ...

# %%
numerical_colm = df.select_dtypes(include = ["number"])

# %%
sns.heatmap(numerical_colm.corr())
# Out:
# <Axes: >

# %%
numerical_colm.corr()['price'].sort_values(ascending=False)
# Out:
# price              1.000000
# price_per_sqft     0.787433
# built_up_area      0.748572
# bathroom           0.609777
# bedRoom            0.591289
# servant room       0.391930
# pooja room         0.319852
# store room         0.305677
# study room         0.242955
# luxury_score       0.091473
# others            -0.013064
# floorNum          -0.087442
# furnishing_type   -0.115194
# Name: price, dtype: float64

# %%
# cols in question

# numerical -> luxury_score, others, floorNum
# categorical -> property_type, sector, agePossession
